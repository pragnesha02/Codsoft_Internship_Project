# %% [markdown]
# <a href="https://colab.research.google.com/github/pragnesha02/Codesoft_Internship_Project/blob/main/IRIS_Flowers_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **IRIS Flower Classification**![iris.jpg](data:image/jpeg;base64,...)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data=pd.read_csv('IRIS.csv')

# %%
print(data.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
print(data.shape)
# Out:
# (150, 5)

# %%
print(data.tail())
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
print(data.describe())
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
print(data.info)
# Out:
# <bound method DataFrame.info of      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]>

# %%
print(data.median())
# Out:
# sepal_length    5.80
# sepal_width     3.00
# petal_length    4.35
# petal_width     1.30
# dtype: float64
# <ipython-input-90-20599fdb1a86>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(data.median())

# %%
print(data.mode())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width          species
# 0           5.0          3.0           1.5          0.2      Iris-setosa
# 1           NaN          NaN           NaN          NaN  Iris-versicolor
# 2           NaN          NaN           NaN          NaN   Iris-virginica

# %%
print(data['species'].value_counts)
# Out:
# <bound method IndexOpsMixin.value_counts of 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: species, Length: 150, dtype: object>

# %%
print(data.columns)
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
print(data.sepal_length)
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
print(data.iloc[1:3])
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa

# %%
print(data.sort_values(by='petal_length',ascending=True))
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 22            4.6          3.6           1.0          0.2     Iris-setosa
# 13            4.3          3.0           1.1          0.1     Iris-setosa
# 14            5.8          4.0           1.2          0.2     Iris-setosa
# 35            5.0          3.2           1.2          0.2     Iris-setosa
# 36            5.5          3.5           1.3          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 131           7.9          3.8           6.4          2.0  Iris-virginica
# 105           7.6          3.0           6.6          2.1  Iris-virginica
# 117           7.7          3.8           6.7          2.2  Iris-virginica
# 122           7.7          2.8           6.7          2.0  Iris-virginica
# 118           7.7          2.6           6.9          2.3  Iris-virginica
#
# [150 rows x 5 columns]

# %%
print(data.drop('petal_width',axis=1))
# Out:
#      sepal_length  sepal_width  petal_length         species
# 0             5.1          3.5           1.4     Iris-setosa
# 1             4.9          3.0           1.4     Iris-setosa
# 2             4.7          3.2           1.3     Iris-setosa
# 3             4.6          3.1           1.5     Iris-setosa
# 4             5.0          3.6           1.4     Iris-setosa
# ..            ...          ...           ...             ...
# 145           6.7          3.0           5.2  Iris-virginica
# 146           6.3          2.5           5.0  Iris-virginica
# 147           6.5          3.0           5.2  Iris-virginica
# 148           6.2          3.4           5.4  Iris-virginica
# 149           5.9          3.0           5.1  Iris-virginica
#
# [150 rows x 4 columns]

# %%
print(data.drop([1,5],axis=0))
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# 6             4.6          3.4           1.4          0.3     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [148 rows x 5 columns]

# %%
print(data.iloc[0:6,1:6])
# Out:
#    sepal_width  petal_length  petal_width      species
# 0          3.5           1.4          0.2  Iris-setosa
# 1          3.0           1.4          0.2  Iris-setosa
# 2          3.2           1.3          0.2  Iris-setosa
# 3          3.1           1.5          0.2  Iris-setosa
# 4          3.6           1.4          0.2  Iris-setosa
# 5          3.9           1.7          0.4  Iris-setosa

# %%
print(data.isnull)
# Out:
# <bound method DataFrame.isnull of      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]>

# %%
print(data.petal_length.sum)
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: petal_length, Length: 150, dtype: float64>

# %%
print(data.sort_values(by='sepal_width',ascending=False))
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          species
# 15            5.7          4.4           1.5          0.4      Iris-setosa
# 33            5.5          4.2           1.4          0.2      Iris-setosa
# 32            5.2          4.1           1.5          0.1      Iris-setosa
# 14            5.8          4.0           1.2          0.2      Iris-setosa
# 16            5.4          3.9           1.3          0.4      Iris-setosa
# ..            ...          ...           ...          ...              ...
# 87            6.3          2.3           4.4          1.3  Iris-versicolor
# 62            6.0          2.2           4.0          1.0  Iris-versicolor
# 68            6.2          2.2           4.5          1.5  Iris-versicolor
# 119           6.0          2.2           5.0          1.5   Iris-virginica
# 60            5.0          2.0           3.5          1.0  Iris-versicolor
#
# [150 rows x 5 columns]

# %%
print(data['sepal_length']>4)
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 145    True
# 146    True
# 147    True
# 148    True
# 149    True
# Name: sepal_length, Length: 150, dtype: bool

# %%
print(data.species[1:10])
# Out:
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# 5    Iris-setosa
# 6    Iris-setosa
# 7    Iris-setosa
# 8    Iris-setosa
# 9    Iris-setosa
# Name: species, dtype: object

# %%
print(data.petal_width.tail())
# Out:
# 145    2.3
# 146    1.9
# 147    2.0
# 148    2.3
# 149    1.8
# Name: petal_width, dtype: float64

# %% [markdown]
# # **Data Visualization**

# %%
sns.barplot(x="sepal_length",y="petal_length",data=data)
print(plt.show())
# Out:
# None

# %%
sns.stripplot(x="sepal_width",y="petal_width",data=data,hue="species",linewidth=1)
print(plt.show())
# Out:
# None

# %%
sns.distplot(data['petal_length'],color="brown")
print(plt.show())
# Out:
# <ipython-input-108-a1d0a329a4df>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['petal_length'],color="brown")
# None

# %%
plt.hist(data['petal_width'],color="olive")
plt.title("Histogram")
plt.xlabel("petal_width")
print(plt.show())
# Out:
# None

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <ipython-input-30-6c71ac866e2e>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True)
# <Axes: >

# %%
sns.pairplot(data,hue="species",palette="mako")

# %% [markdown]
# # **Linear Regression Model**

# %%
from sklearn.model_selection import train_test_split
x=data[['sepal_length']]
y=data[['petal_width','sepal_width']]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)
x_train.head()
# Out:
#      sepal_length
# 84            5.4
# 44            5.1
# 48            5.3
# 149           5.9
# 143           6.8
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12['sepal_length'].plot(kind='hist', bins=20, title='sepal_length')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_13['sepal_length'].plot(kind='line', figsize=(8, 4), title='sepal_length')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
x_test.head()
# Out:
#     sepal_length
# 36           5.5
# 19           5.1
# 46           5.1
# 69           5.6
# 52           6.9
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_14['sepal_length'].plot(kind='hist', bins=20, title='sepal_length')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_15['sepal_length'].plot(kind='line', figsize=(8, 4), title='sepal_length')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
y_train.head()
# Out:
#      petal_width  sepal_width
# 84           1.5          3.0
# 44           0.4          3.8
# 48           0.2          3.7
# 149          1.8          3.0
# 143          2.3          3.2
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_21['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_22['petal_width'].plot(kind='hist', bins=20, title='petal_width')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_23['sepal_width'].plot(kind='hist', bins=20, title='sepal_width')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %%
y_test.head()
# Out:
#     petal_width  sepal_width
# 36          0.2          3.5
# 19          0.3          3.8
# 46          0.2          3.8
# 69          1.1          2.5
# 52          1.5          3.1

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
lr.predict(x_test)
# Out:
# array([[0.96207369, 3.08627312],
#        [0.66119856, 3.11562075],
#        [0.66119856, 3.11562075],
#        [1.03729248, 3.07893621],
#        [2.01513665, 2.98355641],
#        [2.240793  , 2.96154569],
#        [0.28510465, 3.15230528],
#        [1.93991787, 2.99089332],
#        [1.41338639, 3.04225167],
#        [0.43554222, 3.13763147],
#        [2.01513665, 2.98355641],
#        [1.11251126, 3.0715993 ],
#        [1.18773004, 3.06426239],
#        [1.86469908, 2.99823023],
#        [1.7894803 , 3.00556713],
#        [0.96207369, 3.08627312],
#        [1.18773004, 3.06426239],
#        [1.41338639, 3.04225167],
#        [1.33816761, 3.04958858],
#        [0.58597978, 3.12295765],
#        [1.63904274, 3.02024095],
#        [1.18773004, 3.06426239],
#        [1.33816761, 3.04958858],
#        [1.11251126, 3.0715993 ],
#        [1.56382395, 3.02757786],
#        [0.96207369, 3.08627312],
#        [1.11251126, 3.0715993 ],
#        [2.76732447, 2.91018733],
# ...

# %%
y_pred=lr.predict(x_test)
y_test.head()
# Out:
#     petal_width  sepal_width
# 36          0.2          3.5
# 19          0.3          3.8
# 46          0.2          3.8
# 69          1.1          2.5
# 52          1.5          3.1

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,y_pred)
# Out:
# 0.19766833774903153
