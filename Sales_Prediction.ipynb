# %% [markdown]
# <a href="https://colab.research.google.com/github/pragnesha02/Codsoft_Internship_Project/blob/main/Sales_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Sales Prediction**

# %% [markdown]
# ![download.jpg](data:image/jpeg;base64,...)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('Sales Prediction.csv')
print(data.head())
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
print(data.shape)
# Out:
# (200, 4)

# %%
print(data.tail())
# Out:
#         TV  Radio  Newspaper  Sales
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4

# %%
print(data.describe())
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
print(data.isnull())
# Out:
#         TV  Radio  Newspaper  Sales
# 0    False  False      False  False
# 1    False  False      False  False
# 2    False  False      False  False
# 3    False  False      False  False
# 4    False  False      False  False
# ..     ...    ...        ...    ...
# 195  False  False      False  False
# 196  False  False      False  False
# 197  False  False      False  False
# 198  False  False      False  False
# 199  False  False      False  False
#
# [200 rows x 4 columns]

# %%
print(data.sum)
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]>

# %%
print(data.iloc[0:3,0:5])
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0

# %%
print(data.sort_values('Radio',ascending=True))
# Out:
#         TV  Radio  Newspaper  Sales
# 127   80.2    0.0        9.2   11.9
# 107   90.4    0.3       23.2   12.0
# 108   13.1    0.4       25.6    5.3
# 117   76.4    0.8       14.8    9.4
# 157  149.8    1.3       24.3   10.1
# ..     ...    ...        ...    ...
# 128  220.3   49.0        3.2   24.7
# 147  243.2   49.0       44.3   25.4
# 37    74.7   49.4       45.7   14.7
# 55   198.9   49.4       60.0   23.7
# 58   210.8   49.6       37.7   23.8
#
# [200 rows x 4 columns]

# %% [markdown]
# # **Data visualization**

# %%
sns.jointplot(x="TV",y="Radio",data=data,color='y')
print(plt.show())
# Out:
# None

# %%
plt.pie(data['Radio'].head(),labels=data['Sales'].head(),autopct='%0.1f%%')
print(plt.show())
# Out:
# None

# %%
sns.catplot(x="Newspaper",y="Radio",hue="Sales",data=data,color="g")
print(plt.show())
# Out:
# <ipython-input-52-1f81f68dc417>:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:g'` for the same effect.
#
#   sns.catplot(x="Newspaper",y="Radio",hue="Sales",data=data,color="g")
# None

# %%
sns.pairplot(data,hue="Sales",palette="ocean")
print(plt.show())
# Out:
# None

# %%
plt.hist(data['Radio'],color='gray')
print(plt.show())
# Out:
# None

# %% [markdown]
# # **Linear Regration Model**

# %%
from sklearn.model_selection import train_test_split
x=data[['Sales']]
y=data[['Newspaper','TV','Radio']]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)
x_train.head()
# Out:
#      Sales
# 75     8.7
# 180   15.5
# 128   24.7
# 77    14.2
# 151   11.6
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4['Sales'].plot(kind='hist', bins=20, title='Sales')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5['Sales'].plot(kind='line', figsize=(8, 4), title='Sales')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
x_test.head()
# Out:
#      Sales
# 46    10.6
# 99    17.2
# 74    17.0
# 11    17.4
# 182    8.7
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_6['Sales'].plot(kind='hist', bins=20, title='Sales')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_7['Sales'].plot(kind='line', figsize=(8, 4), title='Sales')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
y_train.head()
# Out:
#      Newspaper     TV  Radio
# 75        89.4   16.9   43.7
# 180        8.3  156.6    2.6
# 128        3.2  220.3   49.0
# 77        14.2  120.5   28.5
# 151       48.7  121.0    8.4
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8['Newspaper'].plot(kind='hist', bins=20, title='Newspaper')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['TV'].plot(kind='hist', bins=20, title='TV')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10['Radio'].plot(kind='hist', bins=20, title='Radio')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
y_test.head()
# Out:
#      Newspaper     TV  Radio
# 46        35.7   89.7    9.9
# 99        45.9  135.2   41.7
# 74        13.1  213.4   24.6
# 11         4.0  214.7   24.0
# 182       29.7   56.2    5.7
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_16['Newspaper'].plot(kind='hist', bins=20, title='Newspaper')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17['TV'].plot(kind='hist', bins=20, title='TV')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_18['Radio'].plot(kind='hist', bins=20, title='Radio')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
lr.predict(x_test)
y_pred=lr.predict(x_test)
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,y_pred)
# Out:
# 884.5770402572824
